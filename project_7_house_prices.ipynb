# %% [markdown]
# # 🏠 مشروع التنبؤ بأسعار العقارات والانحدار المتقدم (House Price Prediction & Advanced Regression)
#
# في هذا المشروع، ستمر بخطوات دورة نمذجة الأسعار المتقدمة:
# 1. تنظيف البيانات والتعامل مع القيم المفقودة (KNN Imputer).
# 2. هندسة الميزات وتحويل التوزيعات الملتوية (Log Transformation).
# 3. مقارنة خوارزميات الانحدار المتعددة (Regression Model Battle).
# 4. توليف الموديل باستخدام `GridSearchCV` والتحقق المتبادل.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('datasets/house_prices_data.csv')
print(df.info())
df.head()

# %% [markdown]
# ### 🛠️ الجزء الأول: تحويل التوزيعات وعلاج القيم المفقودة
# تأكد من ملء القيم المفقودة في `square_footage` بمتوسط الحي السكني، وقم بتطبيق التحويل اللوغاريتمي على سعر العقار لتخفيف الالتواء.

# %%
# TODO: Fill missing square_footage using neighborhood average
# TODO: Log transform df['sale_price']
# df['log_price'] = np.log1p(df['sale_price'])

# %% [markdown]
# ### 🤖 الجزء الثاني: مقارنة خوارزميات الانحدار وتوليف المعاملات
# قم بتدريب ومقارنة Linear Regression و Ridge و Lasso و Random Forest Regressor و Gradient Boosting Regressor.

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Prepare features (One-hot encode neighborhood)
# TODO: Compare models and print test RMSE / R-squared
