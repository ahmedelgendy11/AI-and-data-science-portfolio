# %% [markdown]
# # 💬 مشروع معالجة اللغات الطبيعية وتحليل آراء العملاء (NLP Review Sentiment Classifier)
#
# سيمر هذا المشروع بـ:
# 1. تنظيف النصوص وتحضيرها (Text Cleansing).
# 2. تحويل الكلمات لمصفوفة رقمية (TF-IDF Vectorization).
# 3. مقارنة خوارزميات تصنيف النصوص (Multinomial Naive Bayes vs Logistic Regression vs Support Vector Machines).
# 4. تقييم أداء المصنفات بمصفوفة اللخبطة.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('datasets/product_reviews_data.csv')
print(df.info())
df.head()

# %% [markdown]
# ### 🛠️ الجزء الأول: تحويل النصوص ومعالجتها
# قم بتحويل مراجعات العملاء إلى مصفوفة سمات رقمية باستخدام `TfidfVectorizer`.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# TODO: Initialize and fit TfidfVectorizer on review_text
# vectorizer = TfidfVectorizer(stop_words='english')
# X = vectorizer.fit_transform(df['review_text'])

# %% [markdown]
# ### 🤖 الجزء الثاني: مقارنة خوارزميات تصنيف النصوص (Model Battle)
# قم بتدريب ومقارنة Naive Bayes و Logistic Regression و SVC (SVM)، ثم اطبع مصفوفة اللخبطة لأفضل نموذج.

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# TODO: Split, train models, and print classification reports
print("Implement NLP classification comparison here.")
