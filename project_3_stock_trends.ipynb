# %% [markdown]
# # 📈 مشروع الأسهم والتداول الخوارزمي الذكي (Stock Market & Algorithmic Trading Forecaster)
#
# في هذا المشروع ستتعامل مع:
# 1. تحليل العوائد والمخاطر وحساب نسبة شارب (Sharpe Ratio).
# 2. هندسة ميزات مالية (المتوسطات المتحركة ومؤشر القوة النسبية RSI).
# 3. التنبؤ بصعود أو هبوط السهم غداً ومقارنة موديلات الغابة العشوائية و SVM.
# 4. محاكاة استراتيجية تداول خوارزمية (Backtesting).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('datasets/stock_market_data.csv')
print(df.info())
df.head()

# %% [markdown]
# ### 📊 الجزء الأول: التحليل المالي ونسبة شارب
# قم بحساب العوائد اليومية ونسبة شارب السنوية لكل سهم (مع افتراض عائد خالي من المخاطر بنسبة 2%).

# %%
# TODO: Calculate daily returns
# df['daily_return'] = df.groupby('ticker')['close'].pct_change()

# TODO: Calculate Sharpe Ratio
# sharpe = ...
# print(sharpe)

# %% [markdown]
# ### 🛠️ الجزء الثاني: هندسة الميزات المالية (RSI & Moving Averages)
# قم بحساب المتوسطات المتحركة لـ 20 و 50 يوماً ورمز صعود السهم كعمود مستهدف Churn/Target (1 صعود، 0 هبوط).

# %%
# TODO: Compute technical indicators for AAPL
# aapl = df[df['ticker'] == 'AAPL'].copy()
# aapl['SMA_20'] = ...
# aapl['Target'] = (aapl['close'].shift(-1) > aapl['close']).astype(int)

# %% [markdown]
# ### 🤖 الجزء الثالث: التنبؤ بالاتجاه والمحاكاة (Backtesting)
# قم بتدريب الموديل للتنبؤ بالاتجاه غداً، وقم بإنشاء محاكاة تداول بسيطة لقياس أرباح الاستراتيجية.

# %%
# TODO: Train model and perform simple backtesting
print("Implement backtesting here.")
