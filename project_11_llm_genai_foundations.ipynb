# %% [markdown]
# # 🤖 مشروع الذكاء الاصطناعي التوليدي ومبادئ LLMs (GenAI & Basic Vector Search RAG)
#
# في هذا المشروع، ستمر بخطوات:
# 1. هندسة الأوامر (Prompt Engineering) لتقييم النصوص.
# 2. محاكاة استدعاء نموذج لغوي كبير (LLM API call) لمعالجة البيانات.
# 3. بناء نظام RAG مبسط (Vector Search) يعتمد على تشابه الجيب (Cosine Similarity) في NumPy.

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### 🛠️ الجزء الأول: محاكاة استدعاء نموذج لغوي (LLM Zero-Shot Classification)
# اكتب دالة تحاكي استدعاء LLM لتصنيف مشاعر نص المراجعة بناءً على الكلمات المفتاحية الموجودة فيه.

# %%
def mock_llm_sentiment(text):
    # Simulate prompt context: "Analyze sentiment of this product review: ..."
    # TODO: Simple keyword matching to simulate model output
    lower = text.lower()
    if "love" in lower or "great" in lower or "perfect" in lower:
        return "Positive"
    elif "worst" in lower or "terrible" in lower or "broke" in lower:
        return "Negative"
    return "Neutral"

# Test it
print(mock_llm_sentiment("I love this product, it is perfect!"))

# %% [markdown]
# ### 🤖 الجزء الثاني: بناء نظام RAG للبحث النصي المتجهي
# باستخدام مصفوفة TF-IDF، قم بحساب تشابه الجيب (Cosine Similarity) بين نص البحث (query) وقاعدة بيانات المراجعات لاسترجاع المراجعة الأكثر تشابهاً وتغذيتها كـ Context.

# %%
reviews = [
    "I absolutely love this laptop, it is super fast and perfect.",
    "Avoid this watch, it broke down after only two days of use.",
    "The food mixer is okay, nothing special but works fine.",
    "Worst product ever, arrived damaged and extremely cheap quality."
]

# Query: "looking for a fast machine"
# TODO: Calculate TF-IDF, compute cosine similarity of query with reviews, and output top index
print("Implement simple vector search here.")
