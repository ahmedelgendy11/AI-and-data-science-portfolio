# %% [markdown]
# # 🧮 رياضيات وإحصاء علم البيانات الكامل (Mathematics & Statistics for Data Science)
#
# سيمر هذا الملف بأربعة أقسام رئيسية:
# 1. **الجبر الخطي**: تمثيل المتجهات والعمليات عليها وحل المعادلات.
# 2. **حساب التفاضل**: اشتقاق الدوال البرمجية وبناء الانحدار التدريجي (Gradient Descent) من الصفر.
# 3. **نظرية المعلومات**: حساب الإنتروبيا (Entropy) والإنتروبيا المتقاطعة (Cross-Entropy Loss).
# 4. **الإحصاء الاستدلالي**: فترات الثقة واختبار الفرضيات (T-test, ANOVA, Chi-Square).

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd

# %% [markdown]
# ### 📐 الجزء الأول: الجبر الخطي
# قم بضرب مصفوفتين يدوياً في بايثون ومن ثم قارنها بـ `np.dot`.

# %%
# TODO: Multiply two matrices A and B using loops
A = [[1, 2], [3, 4]]
B = [[5, 6], [7, 8]]
# result = ...

# %% [markdown]
# ### 📈 الجزء الثاني: الانحدار التدريجي (Gradient Descent)
# دالة التكلفة هي $f(x) = x^2 - 4x + 4$. قم بإيجاد القيمة الصغرى لها برمجياً من الصفر باستخدام الانحدار التدريجي.

# %%
# f(x) = x^2 - 4x + 4, derivative df/dx = 2*x - 4
x = 10.0 # starting point
learning_rate = 0.1
# TODO: Run loop to perform gradient descent updates
# for _ in range(50): ...
print("Minimum found at x:", x)

# %% [markdown]
# ### 💬 الجزء الثالث: الإحصاء الاستدلالي واختبار الفرضيات
# قم بعمل اختبار t-test مستقل لعينتين لمعرفة هل متوسطهما متطابق إحصائياً أم لا.

# %%
group_a = [23, 25, 28, 30, 21, 22, 29, 27, 26, 24]
group_b = [31, 33, 29, 35, 34, 30, 32, 28, 30, 32]
# TODO: Perform two-sample independent t-test using stats.ttest_ind
# t_stat, p_val = ...
# print("p-value:", p_val)
