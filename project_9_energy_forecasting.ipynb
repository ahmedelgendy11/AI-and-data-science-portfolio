# %% [markdown]
# # ⚡ مشروع السلاسل الزمنية والتنبؤ باستهلاك الطاقة (Smart Grid Time Series Forecaster)
#
# سيمر هذا المشروع بـ:
# 1. تحليل وفصل مكونات السلسلة الزمنية (Trend, Seasonality, Residuals).
# 2. فحص استقرار السلسلة الزمنية باختبار Dickey-Fuller (ADF Test).
# 3. تدريب ومقارنة خوارزميات التنبؤ بالسلاسل الزمنية: ARIMA و SARIMA و Exponential Smoothing.
# 4. مقارنة نسبة الخطأ وتنبؤ قيم الطاقة المستقبلية.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

df = pd.read_csv('datasets/energy_consumption_data.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.set_index('timestamp')
df.head()

# %% [markdown]
# ### 📊 الجزء الأول: تفكيك واختبار استقرار السلسلة
# قم بفصل السلسلة الزمنية ورسم الموسمية، ثم أجرِ اختبار ADF للتأكد من استقرار البيانات إحصائياً.

# %%
# TODO: Perform seasonal decompose
# decomp = seasonal_decompose(df['consumption_kwh'], period=24)
# decomp.plot()

# TODO: Run ADF test
# result = adfuller(df['consumption_kwh'])
# print('ADF p-value:', result[1])

# %% [markdown]
# ### 🤖 الجزء الثاني: نماذج التنبؤ (ARIMA & Exponential Smoothing)
# قم بفصل عينة التدريب والاختبار وتطبيق الموديل وحساب RMSE.

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.arima.model import ARIMA

# TODO: Fit ExponentialSmoothing or ARIMA and print RMSE
print("Implement forecasting comparison here.")
