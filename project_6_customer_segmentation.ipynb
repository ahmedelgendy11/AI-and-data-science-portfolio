# %% [markdown]
# # 👥 مشروع تقسيم فئات العملاء (Customer Segmentation & PCA)
#
# سوف يغطي هذا المشروع المترابط:
# 1. تحليل استكشاف البيانات للمجموعات الديموغرافية.
# 2. تحجيم البيانات وتطبيق خوارزمية K-Means.
# 3. تحديد عدد المجموعات الأمثل عبر طريقة المرفق (Elbow Method).
# 4. تطبيق تقليل الأبعاد PCA لتمثيل المجموعات بيانياً في 2D.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

df = pd.read_csv('datasets/customer_segmentation_data.csv')
print(df.info())
df.head()

# %% [markdown]
# ### 📊 الجزء الأول: طريقة المرفق (Elbow Method)
# قم بحساب القصور الذاتي (Inertia) لعدد مجموعات من 1 إلى 10 وارسمها بيانياً لمعرفة العدد المثالي للمجموعات.

# %%
# TODO: Scale features and calculate inertia for k in range(1, 11)
# X = df[['age', 'annual_income_k', 'spending_score_1_100']]
# X_scaled = ...
# inertias = [] ...

# %% [markdown]
# ### 🤖 الجزء الثاني: التدريب وتقليل الأبعاد باستخدام PCA
# قم بتدريب نموذج K-Means بالعدد الأمثل، ثم قلل الأبعاد إلى بعدين (2 Component) لرسم المجموعات بيانياً.

# %%
# TODO: Train KMeans(n_clusters=optimal_k)
# TODO: Apply PCA(n_components=2) and plot clusters
print("Implement clustering and PCA visualization.")
