# %% [markdown]
# # 🏥 مشروع التشخيص الطبي الذكي والتعلم العميق (Healthcare Diagnostic & Deep Learning)
#
# في هذا المشروع ستتعامل مع:
# 1. استكشاف البيانات وكشف القيم الشاذة (Outliers) بالرسوم البيانية.
# 2. معالجة القيم المفقودة وتحجيم الميزات.
# 3. مقارنة الموديلات التقليدية ورسم منحنيات الـ ROC Curve معاً.
# 4. التعلم العميق: بناء شبكة عصبية من الصفر (NumPy) واستخدام `MLPClassifier`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('datasets/health_risk_data.csv')
print(df.info())
df.head()

# %% [markdown]
# ### 📊 الجزء الأول: تنظيف البيانات والقيم المفقودة
# استبدل القيم المفقودة بالوسيط (median) وقم بتوحيد فئات عمود `gender`.

# %%
# TODO: Fill missing values with median
# TODO: Standardize gender values to 'Male' or 'Female'
# df['gender'] = df['gender'].replace(...)

# %% [markdown]
# ### 🤖 الجزء الثاني: مقارنة نماذج الذكاء الاصطناعي ورسم ROC Curve
# قم بتدريب Logistic Regression و Random Forest و SVM، وارسم منحنيات الـ ROC للمقارنة بوضوح.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, auc

# Prepare features (One-hot encode gender/smoking)
# TODO: Train and plot ROC comparison
print("Implement ROC comparison here.")

# %% [markdown]
# ### 🧠 الجزء الثالث: التعلم العميق (Deep Learning)
# قم بتطبيق التمرير الأمامي (Forward Pass) لخلية عصبية (Neuron) واحدة بـ NumPy من الصفر، ثم قم بتدريب `MLPClassifier`.

# %%
# 1. Forward Pass of a Neuron
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def forward_neuron(inputs, weights, bias):
    # TODO: Calculate net input and return output after activation
    return 0.0

# 2. MLP Classifier in action
from sklearn.neural_network import MLPClassifier
# TODO: Train MLP and compare accuracy
