# %% [markdown]
# # 🛒 مشروع التجارة الإلكترونية المتكامل: التنبؤ برحيل العملاء (E-Commerce Analysis & Churn Prediction)
#
# في هذا المشروع، ستمر بدورة العمل الكاملة لعالم البيانات:
# 1. استكشاف البيانات (EDA)
# 2. تنظيف البيانات والتعامل مع التواريخ والقيم المفقودة
# 3. تحليل RFM ومجموعات العملاء (Cohort Analysis)
# 4. هندسة الميزات (Feature Engineering)
# 5. بناء نماذج التعلم الآلي وتدريبها ومقارنتها للتنبؤ برحيل العملاء (Churn Prediction)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load data
df = pd.read_csv('datasets/ecommerce_transactions.csv')
print("Shape:", df.shape)
df.head()

# %% [markdown]
# ### 🛠️ الجزء الأول: تنظيف البيانات والتواريخ
# قم بتحويل العمود `order_date` إلى صيغة تاريخ موحدة وإزالة المعاملات المكررة.

# %%
# TODO: Convert order_date to datetime format
# df['order_date'] = ...

# TODO: Remove duplicate rows
# df = ...

# Confirm types
print(df.dtypes)

# %% [markdown]
# ### 📊 الجزء الثاني: تحليل RFM و Cohort
# قم بحساب Recency و Frequency و Monetary لكل عميل وتصنيفهم.

# %%
# Calculate RFM
# TODO: Calculate days since last order (Recency), count of orders (Frequency), and sum of amounts (Monetary)
# rfm = ...
# rfm.head()

# %% [markdown]
# ### 🤖 الجزء الثالث: التنبؤ برحيل العملاء ومقارنة الموديلات
# قم ببناء عمود Churn (العميل الذي لم يطلب في آخر 90 يوماً)، وقم بتدريب ومقارنة 3 موديلات تصنيف: Logistic Regression و Random Forest و Gradient Boosting.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, accuracy_score, f1_score

# Prepare features & target
# TODO: Train models and print comparisons
print("Implement model comparison here.")
